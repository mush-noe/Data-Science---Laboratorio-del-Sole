# %%
from IPython.display import HTML

with open("Stile.css") as f:
    css_content = f.read()

HTML(f"<style>{css_content}</style>")
print(len(css_content))
print("io sto girando")
print(css_content)
# Out:
# 1161
# io sto girando
# .reveal h1 {
#     font-family:'Arial', sans-serif !important;
#     font-size: 3em !important;
#     font-weight: bold !important;
# }
#
# /* â”€â”€ Titolo secondario â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ */
# .reveal h2 {
#     font-family:'Arial', sans-serif !important;
#     font-size: 2em !important;
#     font-weight: bold !important;
# }
#
# /* â”€â”€ Titolo terziario â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ */
# .reveal h3 {
#     font-family: 'Arial', sans-serif !important;
#     font-size: 1.5em !important;
#     font-weight: normal !important;
# }
#
# ...

# %%
from IPython.display import HTML
html_test = f"<style>{css_content}</style><h1>TEST TITOLO</h1>"
HTML(html_test)
# Out:
# <style>.reveal h1 {
#     font-family:'Arial', sans-serif !important;
#     font-size: 3em !important;
#     font-weight: bold !important;
# }
#
# /* â”€â”€ Titolo secondario â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ */
# .reveal h2 {
#     font-family:'Arial', sans-serif !important;
#     font-size: 2em !important;
#     font-weight: bold !important;
# }
#
# /* â”€â”€ Titolo terziario â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ */
# .reveal h3 {
#     font-family: 'Arial', sans-serif !important;
#     font-size: 1.5em !important;
#     font-weight: normal !important;
# }
#
# ...

# %% [markdown]
# # Laboratorio Del Sole
# ## Progetto artigianale di Noemi Fain
# Analisi autunno 2023 - estate 2026

# %% [markdown]
# # Introduzione

# %% [markdown]
# ## Da dove è nato?
# ### La storia
# Nell'estate del 2022 comprai del filo di rame per sperimentare una tecnica di realizzazione di gioielli.
# Un anno dopo amici e parenti mi chiesero le prime commissioni.
# Nel giugno del 2024 il primo mercatino.
#
# ### L'obiettivo
# Realizzare qualcosa di durevole ed esteticamente piacevole in un materiale tradizionale.

# %% [markdown]
# ## Domande
# - Quale mercatino mi ha impegnato di più? Dove?
# - Come si distribuiscono le vendite rispetto le stagioni?
# - Il rapporto prezzo / ora è aumentato all'aumentare dell'esperienza?
# - Quale tipo di gioiello viene venduto più frequentemente?
# - Quanti di questi gioielli hanno un disegno originale?
# - Quali sono i tipi di gioiello più pesanti?
# - Le ore di lavoro crescono pari passo con il peso?
# - Sono meglio più pezzi piccoli o uno grande?

# %% [markdown]
# # I dati utilizzati

# %% [markdown]
# ## Fonte
# Dati privati raccolti tra:
# - foto scattate
# - riepiloghi dei mercatini
# - misurazioni dirette

# %% [markdown]
# ## Contenuto
# Dati sui gioielli: per ognuno dei 83 modelli prodotti
# - caratteristiche del gioiello:
#     - tipologia (tra ciondoli, orecchini, anelli, bracciali e altro)
#     - ore impiegate
#     - prezzo di vendita
#     - peso (in grammi)
#     - se il design è originale
#     - se ci sono perline
# - storico delle vendite: pezzi rimasti, regalati, mercatini e commissione (autunno 2023 - estate 2026)
#
# Dati sui mercatini: per ognuno dei 5 mercatini fatti
# - luogo e coordinate
# - durata in giorni
# - nome dell'evento

# %% [markdown]
# # Domande

# %% [markdown]
# ## Quale mercatino mi ha impegnato di più? Dove?

# %%
from IPython.display import Image
Image(filename = "Immagini/Mappa.png")

# %% [markdown]
# ## Come si distribuiscono le vendite?

# %%
Image(filename = "Immagini/Passaparola-Mercatini.png")

# %% [markdown]
# ## Il prezzo / ora è aumentato nel tempo?

# %%
Image(filename = "Immagini/Prezzo-Ora.png")

# %% [markdown]
# ## Quali tipi vendono di più?

# %%
Image(filename = "Immagini/Tipologie.png")

# %% [markdown]
# ## Quanti hanno un disegno originale?

# %%
Image(filename = "Immagini/Tipologia-design.png")

# %% [markdown]
# ## Quali sono i tipi più pesanti?
# Confronto: presenza di perline e origine del design

# %%
Image(filename = "Immagini/Peso.png")

# %% [markdown]
# ## Il peso è proporzionale alle ore?
# Analisi degli oggetti con peso minore a 8g

# %%
Image(filename = "Immagini/Peso-ore.png")

# %% [markdown]
# ## Meglio più pezzi piccoli o uno grande?

# %%
Image(filename = "Media-prezzo-ora.png")

# %% [markdown]
# # Conclusioni
# - Il mercatino in rievocazione storica è quello che mi ha impegnato di più
# - Esclusi i mercatini, il periodo di maggior vendite è quello invernale
# - Il rapporto prezzo è cresciuto molto all'inizio, per poi rallentare
# - Ai mercatini tutti i tipi si vendono in modo simile, mentre tra le commissioni e i regali prevalgono ciondoli e orecchini
# - I gioielli con perline sono più leggeri
# - Le ore di lavoro crescono assieme al peso
# - Conviene concentrarsi su pezzi di massimo 3 ore di lavoro, mai più di 5

# %%
print(f"<style>{css_content}</style>"[:500])
# Out:
# <style>.reveal h1 {
#     font-family:'Arial', sans-serif !important;
#     font-size: 3em !important;
#     font-weight: bold !important;
# }
#
# /* â”€â”€ Titolo secondario â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€ */
# .reveal h2 {
#     font-family:'Arial', sans-serif !important;
#     font-size: 2em !important;
#     font-weight: bold !important;
# }
#
# /* â”€â”€ Titolo terziario â”€â”€â”€â”€â”€
